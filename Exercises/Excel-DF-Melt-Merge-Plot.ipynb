# %%
"""
Enter your full name here: Patrick Thomas Doyne

"""
# Out:
# '\nEnter your full name here: Patrick Thomas Doyne\n\n'

# %% [markdown]
# **Complete the problems below. Structure your code in multiple lines as needed.
# Submit your completed pdf and jupyter files to Blackboard.**

# %%
#Run this cell first before moving on
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
# %matplotlib inline

# %%
#Use the variables/urls to load the data
# url for covid cases:  
covid_cases = "https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv"

# url for covid deaths: 
covid_deaths = "https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv"

# It is okay to have a horizontal scroll bar for this cell.
df_cases = pd.read_csv(covid_cases)
df_deaths = pd.read_csv(covid_deaths) # include covid_deaths variable in place of ---

# %%
#Run the cell, review the output, and move to the next cell
df_cases
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0     84001001   US  USA    840   1001.0     Autauga        Alabama
# 1     84001003   US  USA    840   1003.0     Baldwin        Alabama
# 2     84001005   US  USA    840   1005.0     Barbour        Alabama
# 3     84001007   US  USA    840   1007.0        Bibb        Alabama
# 4     84001009   US  USA    840   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 3337  84056039   US  USA    840  56039.0       Teton        Wyoming
# 3338  84056041   US  USA    840  56041.0       Uinta        Wyoming
# 3339  84090056   US  USA    840  90056.0  Unassigned        Wyoming
# 3340  84056043   US  USA    840  56043.0    Washakie        Wyoming
# 3341  84056045   US  USA    840  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_  ... 2/28/23  3/1/23  3/2/23  \
# 0                US  32.539527  -86.644082  ...   19732   19759   19759
# 1                US  30.727750  -87.722071  ...   69641   69767   69767
# 2                US  31.868263  -85.387129  ...    7451    7474    7474
# 3                US  32.996421  -87.125115  ...    8067    8087    8087
# 4                US  33.982109  -86.567906  ...   18616   18673   18673
# ...             ...        ...         ...  ...     ...     ...     ...
# 3337             US  43.935225 -110.589080  ...   12130   12130   12130
# 3338             US  41.287818 -110.547578  ...    6401    6401    6401
# 3339             US   0.000000    0.000000  ...       0       0       0
# 3340             US  43.904516 -107.680187  ...    2750    2750    2750
# 3341             US  43.839612 -104.567488  ...    1905    1905    1905
#
#       3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0      19759   19759   19759   19759   19759   19790   19790
# 1      69767   69767   69767   69767   69767   69860   69860
# 2       7474    7474    7474    7474    7474    7485    7485
# 3       8087    8087    8087    8087    8087    8091    8091
# 4      18673   18673   18673   18673   18673   18704   18704
# ...      ...     ...     ...     ...     ...     ...     ...
# 3337   12130   12130   12130   12130   12134   12134   12134
# 3338    6401    6401    6401    6401    6406    6406    6406
# 3339       0       0       0       0       0       0       0
# 3340    2750    2750    2750    2750    2755    2755    2755
# 3341    1905    1905    1905    1905    1905    1905    1905
#
# [3342 rows x 1154 columns]

# %%
#Run the cell, review the output, and move to the next cell
df_deaths
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0     84001001   US  USA    840   1001.0     Autauga        Alabama
# 1     84001003   US  USA    840   1003.0     Baldwin        Alabama
# 2     84001005   US  USA    840   1005.0     Barbour        Alabama
# 3     84001007   US  USA    840   1007.0        Bibb        Alabama
# 4     84001009   US  USA    840   1009.0      Blount        Alabama
# ...        ...  ...  ...    ...      ...         ...            ...
# 3337  84056039   US  USA    840  56039.0       Teton        Wyoming
# 3338  84056041   US  USA    840  56041.0       Uinta        Wyoming
# 3339  84090056   US  USA    840  90056.0  Unassigned        Wyoming
# 3340  84056043   US  USA    840  56043.0    Washakie        Wyoming
# 3341  84056045   US  USA    840  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_  ... 2/28/23  3/1/23  3/2/23  \
# 0                US  32.539527  -86.644082  ...     230     232     232
# 1                US  30.727750  -87.722071  ...     724     726     726
# 2                US  31.868263  -85.387129  ...     103     103     103
# 3                US  32.996421  -87.125115  ...     109     109     109
# 4                US  33.982109  -86.567906  ...     261     261     261
# ...             ...        ...         ...  ...     ...     ...     ...
# 3337             US  43.935225 -110.589080  ...      16      16      16
# 3338             US  41.287818 -110.547578  ...      43      43      43
# 3339             US   0.000000    0.000000  ...       0       0       0
# 3340             US  43.904516 -107.680187  ...      50      50      50
# 3341             US  43.839612 -104.567488  ...      23      23      23
#
#       3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0        232     232     232     232     232     232     232
# 1        726     726     726     726     726     727     727
# 2        103     103     103     103     103     103     103
# 3        109     109     109     109     109     109     109
# 4        261     261     261     261     261     261     261
# ...      ...     ...     ...     ...     ...     ...     ...
# 3337      16      16      16      16      16      16      16
# 3338      43      43      43      43      43      43      43
# 3339       0       0       0       0       0       0       0
# 3340      50      50      50      50      51      51      51
# 3341      23      23      23      23      23      23      23
#
# [3342 rows x 1155 columns]

# %%
"""Problem 0"""
# Run the cell, notice the additional data column in df_deaths which will be remove in problem 1b.
print("Cases DataFrame:", list(df_cases.columns[0:12]))
print("") # Do not modify - this displays blank line for space between the Cases and Deaths output
print("Deaths DataFrame:", list(df_deaths.columns[0:13]))
# Out:
# Cases DataFrame: ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Lat', 'Long_', 'Combined_Key', '1/22/20']
#
# Deaths DataFrame: ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Population', '1/22/20']

# %%
"""Problem 1a"""
#Remove the following columns for df_cases using the drop method: 
  # "UID", "iso2", "iso3", "code3", "FIPS", "Country_Region", 
  # "Lat", "Long_"
# Use the inplace=True.

df_cases.drop(columns=["UID","iso2", "iso3", "code3", "FIPS", "Country_Region",  "Lat", "Long_"],  
              inplace=True)   #remove --- and enter the columns names in the list, each as a string. 
df_cases.head()
# Out:
#     Admin2 Province_State          Combined_Key  1/22/20  1/23/20  1/24/20  \
# 0  Autauga        Alabama  Autauga, Alabama, US        0        0        0
# 1  Baldwin        Alabama  Baldwin, Alabama, US        0        0        0
# 2  Barbour        Alabama  Barbour, Alabama, US        0        0        0
# 3     Bibb        Alabama     Bibb, Alabama, US        0        0        0
# 4   Blount        Alabama   Blount, Alabama, US        0        0        0
#
#    1/25/20  1/26/20  1/27/20  1/28/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...    19732   19759   19759   19759
# 1        0        0        0        0  ...    69641   69767   69767   69767
# 2        0        0        0        0  ...     7451    7474    7474    7474
# 3        0        0        0        0  ...     8067    8087    8087    8087
# 4        0        0        0        0  ...    18616   18673   18673   18673
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0   19759   19759   19759   19759   19790   19790
# 1   69767   69767   69767   69767   69860   69860
# 2    7474    7474    7474    7474    7485    7485
# 3    8087    8087    8087    8087    8091    8091
# 4   18673   18673   18673   18673   18704   18704
#
# [5 rows x 1146 columns]

# %%
"""Problem 1b"""
#Remove the same columns for df_deaths but also include the extra data column in df_deaths: 
df_deaths.drop(columns=["UID","iso2", "iso3", "code3", "FIPS", 
                        "Country_Region",  "Lat", "Long_", "Population"],
               inplace=True)   #remove --- and enter code
df_deaths.tail(3)
# Out:
#           Admin2 Province_State             Combined_Key  1/22/20  1/23/20  \
# 3339  Unassigned        Wyoming  Unassigned, Wyoming, US        0        0
# 3340    Washakie        Wyoming    Washakie, Wyoming, US        0        0
# 3341      Weston        Wyoming      Weston, Wyoming, US        0        0
#
#       1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  2/28/23  3/1/23  \
# 3339        0        0        0        0        0  ...        0       0
# 3340        0        0        0        0        0  ...       50      50
# 3341        0        0        0        0        0  ...       23      23
#
#       3/2/23  3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 3339       0       0       0       0       0       0       0       0
# 3340      50      50      50      50      50      51      51      51
# 3341      23      23      23      23      23      23      23      23
#
# [3 rows x 1146 columns]

# %%
"""Problem 2"""
#Rename the following columns for both dataframes using the rename method:
# Admin2 to county, Province_State to state, Combined_key to county_state

print("Before rename:", list(df_cases.columns)) # displays data column names for df_cases
df_cases.rename(columns={"Admin2":"county","Province_State":"state","Combined_Key":"county_state"}, inplace=True)
print("After rename:", list(df_cases.columns)) 

print("") 

print("Before rename:", list(df_deaths.columns)) # displays data column names for df_deaths
df_deaths.rename(columns={"Admin2":"county","Province_State":"state","Combined_Key":"county_state"}, inplace=True)
print(list(df_deaths.columns)) # displays data column names for df_deaths
# Out:
# Before rename: ['Admin2', 'Province_State', 'Combined_Key', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20', '4/15/20', '4/16/20', '4/17/20', '4/18/20', '4/19/20', '4/20/20', '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20', '4/27/20', '4/28/20', '4/29/20', '4/30/20', '5/1/20', '5/2/20', '5/3/20', '5/4/20', '5/5/20', '5/6/20', '5/7/20', '5/8/20', '5/9/20', '5/10/20', '5/11/20', '5/12/20', '5/13/20', '5/14/20', '5/15/20', '5/16/20', '5/17/20', '5/18/20', '5/19/20', '5/20/20', '5/21/20', '5/22/20', '5/23/20', '5/24/20', '5/25/20', '5/26/20', '5/27/20', '5/28/20', '5/29/20', '5/30/20', '5/31/20', '6/1/20', '6/2/20', '6/3/20', '6/4/20', '6/5/20', '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20', '6/13/20', '6/14/20', '6/15/20', '6/16/20', '6/17/20', '6/18/20', '6/19/20', '6/20/20', '6/21/20', '6/22/20', '6/23/20', '6/24/20', '6/25/20', '6/26/20', '6/27/20', '6/28/20', '6/29/20', '6/30/20', '7/1/20', '7/2/20', '7/3/20', '7/4/20', '7/5/20', '7/6/20', '7/7/20', '7/8/20', '7/9/20', '7/10/20', '7/11/20', '7/12/20', '7/13/20', '7/14/20', '7/15/20', '7/16/20', '7/17/20', '7/18/20', '7/19/20', '7/20/20', '7/21/20', '7/22/20', '7/23/20', '7/24/20', '7/25/20', '7/26/20', '7/27/20', '7/28/20', '7/29/20', '7/30/20', '7/31/20', '8/1/20', '8/2/20', '8/3/20', '8/4/20', '8/5/20', '8/6/20', '8/7/20', '8/8/20', '8/9/20', '8/10/20', '8/11/20', '8/12/20', '8/13/20', '8/14/20', '8/15/20', '8/16/20', '8/17/20', '8/18/20', '8/19/20', '8/20/20', '8/21/20', '8/22/20', '8/23/20', '8/24/20', '8/25/20', '8/26/20', '8/27/20', '8/28/20', '8/29/20', '8/30/20', '8/31/20', '9/1/20', '9/2/20', '9/3/20', '9/4/20', '9/5/20', '9/6/20', '9/7/20', '9/8/20', '9/9/20', '9/10/20', '9/11/20', '9/12/20', '9/13/20', '9/14/20', '9/15/20', '9/16/20', '9/17/20', '9/18/20', '9/19/20', '9/20/20', '9/21/20', '9/22/20', '9/23/20', '9/24/20', '9/25/20', '9/26/20', '9/27/20', '9/28/20', '9/29/20', '9/30/20', '10/1/20', '10/2/20', '10/3/20', '10/4/20', '10/5/20', '10/6/20', '10/7/20', '10/8/20', '10/9/20', '10/10/20', '10/11/20', '10/12/20', '10/13/20', '10/14/20', '10/15/20', '10/16/20', '10/17/20', '10/18/20', '10/19/20', '10/20/20', '10/21/20', '10/22/20', '10/23/20', '10/24/20', '10/25/20', '10/26/20', '10/27/20', '10/28/20', '10/29/20', '10/30/20', '10/31/20', '11/1/20', '11/2/20', '11/3/20', '11/4/20', '11/5/20', '11/6/20', '11/7/20', '11/8/20', '11/9/20', '11/10/20', '11/11/20', '11/12/20', '11/13/20', '11/14/20', '11/15/20', '11/16/20', '11/17/20', '11/18/20', '11/19/20', '11/20/20', '11/21/20', '11/22/20', '11/23/20', '11/24/20', '11/25/20', '11/26/20', '11/27/20', '11/28/20', '11/29/
2/20', '12/3/20', '12/4/20', '12/5/20', '12/6/20', '12/7/20', '12/8/20', '12/9/20', '12/10/20', '12/11/20', '12/12/20', '12/13/20', '12/14/20', '12/15/20', '12/16/20', '12/17/20', '12/18/20', '12/19/20', '12/20/20', '12/21/20', '12/22/20', '12/23/20', '12/24/20', '12/25/20', '12/26/20', '12/27/20', '12/28/20', '12/29/20', '12/30/20', '12/31/20', '1/1/21', '1/2/21', '1/3/21', '1/4/21', '1/5/21', '1/6/21', '1/7/21', '1/8/21', '1/9/21', '1/10/21', '1/11/21', '1/12/21', '1/13/21', '1/14/21', '1/15/21', '1/16/21', '1/17/21' ...

# %%
"""Problem 3"""
#Melt/reshape df_cases. Columns to assign to 
    # the id_vars parameter are: county, state, and county_state.
# Make sure that var_name="dates" and value_name="cases" 
#Complete the melt function code below.
df_cases_melted = pd.melt(df_cases, id_vars=["county","state","county_state"]
                          , var_name="dates", value_name="cases")
df_cases_melted.tail(3)
# Out:
#              county    state             county_state   dates  cases
# 3819903  Unassigned  Wyoming  Unassigned, Wyoming, US  3/9/23      0
# 3819904    Washakie  Wyoming    Washakie, Wyoming, US  3/9/23   2755
# 3819905      Weston  Wyoming      Weston, Wyoming, US  3/9/23   1905

# %%
"""Problem 4"""
#Melt/reshape df_deaths. Columns to assign to 
    # the id_vars parameter are: county, state, and county_state.
#Make sure that var_name="dates" and value_name="deaths" 
#Complete the melt function code below.

df_deaths_melted = pd.melt(df_deaths , id_vars = ["county","state","county_state"]
                           ,var_name = "dates", value_name="deaths")
df_deaths_melted.tail(3)
# Out:
#              county    state             county_state   dates  deaths
# 3819903  Unassigned  Wyoming  Unassigned, Wyoming, US  3/9/23       0
# 3819904    Washakie  Wyoming    Washakie, Wyoming, US  3/9/23      51
# 3819905      Weston  Wyoming      Weston, Wyoming, US  3/9/23      23

# %%
"""Problem 5"""
#Merge the melted dataframes for cases and deaths.
#Complete the merged function code below.

df_merged = pd.merge(df_cases_melted, df_deaths_melted, how = "left" , 
                     on= ["county","state","county_state","dates"])
df_merged.tail()
# Out:
#              county    state             county_state   dates  cases  deaths
# 3819901       Teton  Wyoming       Teton, Wyoming, US  3/9/23  12134      16
# 3819902       Uinta  Wyoming       Uinta, Wyoming, US  3/9/23   6406      43
# 3819903  Unassigned  Wyoming  Unassigned, Wyoming, US  3/9/23      0       0
# 3819904    Washakie  Wyoming    Washakie, Wyoming, US  3/9/23   2755      51
# 3819905      Weston  Wyoming      Weston, Wyoming, US  3/9/23   1905      23

# %%
"""Problem 6"""
#Using df_merged, change data type for dates to a datetime object. 

df_merged.dates = pd.to_datetime(df_merged["dates"])
df_merged.dtypes
# Out:
# C:\Users\Patrick Doyne\AppData\Local\Temp\ipykernel_23372\2170152627.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_merged.dates = pd.to_datetime(df_merged["dates"])
# county                  object
# state                   object
# county_state            object
# dates           datetime64[ns]
# cases                    int64
# deaths                   int64
# dtype: object

# %%
"""Problem 7"""
#Calculate the number of days into the outbreak for each record. 
#The name of the new column will be us_outbreak

df_merged["us_outbreak"] = df_merged["dates"]- df_merged["dates"].min()
df_merged[["dates", "us_outbreak"]].iloc[-1] # this code outputs the number of days since the outbreak (Day 0)
# Out:
# dates          2023-03-09 00:00:00
# us_outbreak     1142 days 00:00:00
# Name: 3819905, dtype: object

# %%
#Run cell, review the dataframe output which include the new column (us_outbreak)
df_merged
# Out:
#              county    state             county_state      dates  cases  \
# 0           Autauga  Alabama     Autauga, Alabama, US 2020-01-22      0
# 1           Baldwin  Alabama     Baldwin, Alabama, US 2020-01-22      0
# 2           Barbour  Alabama     Barbour, Alabama, US 2020-01-22      0
# 3              Bibb  Alabama        Bibb, Alabama, US 2020-01-22      0
# 4            Blount  Alabama      Blount, Alabama, US 2020-01-22      0
# ...             ...      ...                      ...        ...    ...
# 3819901       Teton  Wyoming       Teton, Wyoming, US 2023-03-09  12134
# 3819902       Uinta  Wyoming       Uinta, Wyoming, US 2023-03-09   6406
# 3819903  Unassigned  Wyoming  Unassigned, Wyoming, US 2023-03-09      0
# 3819904    Washakie  Wyoming    Washakie, Wyoming, US 2023-03-09   2755
# 3819905      Weston  Wyoming      Weston, Wyoming, US 2023-03-09   1905
#
#          deaths us_outbreak
# 0             0      0 days
# 1             0      0 days
# 2             0      0 days
# 3             0      0 days
# 4             0      0 days
# ...         ...         ...
# 3819901      16   1142 days
# 3819902      43   1142 days
# 3819903       0   1142 days
# 3819904      51   1142 days
# 3819905      23   1142 days
#
# [3819906 rows x 7 columns]

# %%
"""
After completing problem 7, run this cell and review the output.
Understand what the as_index parameter does.
"""
df = df_merged.groupby(["us_outbreak", "dates"], as_index=False)["cases"].sum()
df.tail()
# Out:
#      us_outbreak      dates      cases
# 1138   1138 days 2023-03-05  103646975
# 1139   1139 days 2023-03-06  103655539
# 1140   1140 days 2023-03-07  103690910
# 1141   1141 days 2023-03-08  103755771
# 1142   1142 days 2023-03-09  103802702

# %%
"""Problem 8"""
#Using df from above, create a derived data column using the diff method on cases.
#The name of the new column is: new_cases

df["new_cases"] = df['cases'].diff()
df.tail(6)
# Out:
#      us_outbreak      dates      cases  new_cases
# 1137   1137 days 2023-03-04  103650837     2147.0
# 1138   1138 days 2023-03-05  103646975    -3862.0
# 1139   1139 days 2023-03-06  103655539     8564.0
# 1140   1140 days 2023-03-07  103690910    35371.0
# 1141   1141 days 2023-03-08  103755771    64861.0
# 1142   1142 days 2023-03-09  103802702    46931.0

# %%
""" Problem 9 """
#Use plt.bar() function to create a bar plot,
# have the dates on the x-axis and new_cases on the y-axis.
#Provide x & y axis labels and an appropriate chart title that
#  explains visual. 
#Rotate the x-axis ticks to 45 using the xticks function.
# Below are the functions used - complete the code:

plt.figure(figsize = (6,6)) # include figsize keyword argument
plt.bar(df["dates"],df["new_cases"])
plt.xticks(rotation=45) # include rotation keyword argument
plt.xlabel("Date")
plt.ylabel("Cases (in millions)")
plt.title("New Cases of COVID-19")
plt.tight_layout()
plt.show()

# %% [markdown]
# SAMPLE
# ![image.png](attachment:image.png)

# %%
""" Problem 10 """
# Provide the code that shows what the average number of 
# new_cases that were reported in 2021

print(df.query("dates >= 2021 & dates < 2022")['new_cases'].mean())
# Out:
# 95035.22465753424
